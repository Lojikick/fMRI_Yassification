# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install numpy==1.24.3 pandas scikit-learn scipy matplotlib pillow nibabel easydict
# !pip install absl-py antlr4-python3-runtime anyio openai-clip einops fire ftfy huggingface-hub kornia lpips opencv-python omegaconf transformers==4.19.2 tensorboardx

# %%
print("wassup")
# Out:
# wassup

# %%
print("Whats up world")
# Out:
# Whats up world

# %%
import easydict

# %%
import sys
sys.path.append('versatile_diffusion')

# %%
from lib.cfg_helper import model_cfg_bank

# %%
import torch

# Check CUDA availability
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
    print(f"CUDA version: {torch.version.cuda}")

# Your device-agnostic setup
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    elif torch.backends.mps.is_available():
        return torch.device("mps")
    else:
        return torch.device("cpu")

device = get_device()
print(f"Using device: {device}")
# Out:
# CUDA available: True
# CUDA device: Tesla T4
# CUDA version: 12.1
# Using device: cuda

# %% [markdown]
# **Connect Database to Google Colab**

# %%
# !pip install gdown

# !gdown --id 1B8J7q0tX9qhZUCkdyjyLvzchOeZwiBZ8 -O filename.zip
# !wget --no-check-certificate "https://drive.google.com/file/d/1B8J7q0tX9qhZUCkdyjyLvzchOeZwiBZ8/view?usp=drive_link" -O filename.zip
# !unzip filename.zip -d /content
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1B8J7q0tX9qhZUCkdyjyLvzchOeZwiBZ8
# From (redirected): https://drive.google.com/uc?id=1B8J7q0tX9qhZUCkdyjyLvzchOeZwiBZ8&confirm=t&uuid=c9752706-2eeb-4629-9452-1f1790f99f8a
# To: /content/filename.zip
# 100% 6.12G/6.12G [01:29<00:00, 68.2MB/s]
# Archive:  filename.zip
#    creating: /content/subj01/
#   inflating: /content/subj01/nsd_train_fmriavg_nsdgeneral_sub1.npy
#   inflating: /content/__MACOSX/subj01/._nsd_train_fmriavg_nsdgeneral_sub1.npy
#   inflating: /content/subj01/nsd_test_stim_sub1.npy
#   inflating: /content/__MACOSX/subj01/._nsd_test_stim_sub1.npy
#   inflating: /content/subj01/nsd_test_fmriavg_nsdgeneral_sub1.npy
#   inflating: /content/__MACOSX/subj01/._nsd_test_fmriavg_nsdgeneral_sub1.npy
#   inflating: /content/subj01/.gitignore
#   inflating: /content/subj01/nsd_train_stim_sub1.npy
#   inflating: /content/__MACOSX/subj01/._nsd_train_stim_sub1.npy
#   inflating: /content/subj01/nsd_train_cap_sub1.npy
#   inflating: /content/__MACOSX/subj01/._nsd_train_cap_sub1.npy
#   inflating: /content/subj01/nsd_test_cap_sub1.npy
#   inflating: /content/__MACOSX/subj01/._nsd_test_cap_sub1.npy

# %%
 # First make sure your Drive is mounted
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/brain_diffuser_data/lib')

# %%
# !pwd  # Shows current directory
# !ls -la '/content/drive/MyDrive/brain_diffuser_data'  # Lists all files including hidden ones
# Out:
# /content
# total 5971892
# -rw------- 1 root root       3779 Nov 17 21:24 'First Phase.ipynb'
# drwx------ 7 root root       4096 Nov 29 23:56  lib
# drwx------ 2 root root       4096 Nov 16 21:33  Paper_code
# -rw------- 1 root root        414 Nov 16 23:02  requirements.txt
# -rw------- 1 root root      24011 Nov 30 00:06  Second_Phase_Code.ipynb
# -rw------- 1 root root 6115180473 Nov 10 19:44  subj01.zip

# %%
# Now you should be able to import
from lib.cfg_helper import model_cfg_bank
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-af28349ff2ac> in <cell line: 2>()
#       1 # Now you should be able to import
# ----> 2 from lib.cfg_helper import model_cfg_bank
#
# ModuleNotFoundError: No module named 'lib.cfg_helper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !ls '/content/drive/MyDrive/brain_diffuser_data/lib/'
# %cd /content/drive/MyDrive/brain_diffuser_data/
# Out:
# cfg_helper.py  data_factory  experiments  log_service.py  __pycache__  utils.py
# cfg_holder.py  evaluator     __init__.py  model_zoo	  sync.py
# /content/drive/MyDrive/brain_diffuser_data

# %%
# !ls
# Out:
# 'First Phase.ipynb'   lib   Paper_code	 requirements.txt   Second_Phase_Code.ipynb   subj01.zip

# %%
# %cd /content/drive/MyDrive/brain_diffuser_data/lib
# Out:
# /content/drive/MyDrive/brain_diffuser_data/lib

# %%
# !ls
# Out:
# cfg_helper.py  data_factory  experiments  log_service.py  __pycache__  utils.py
# cfg_holder.py  evaluator     __init__.py  model_zoo	  sync.py

# %%
# %cd /content/drive/MyDrive/brain_diffuser_data/
# Out:
# /content/drive/MyDrive/brain_diffuser_data

# %%
#CLIP Vision extraction Processing:
import sys
import numpy as np
import os
import PIL
from PIL import Image

# %%
from lib.cfg_helper import model_cfg_bank
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-03defc745a45> in <cell line: 1>()
# ----> 1 from lib.cfg_helper import model_cfg_bank
#
# ModuleNotFoundError: No module named 'lib.cfg_helper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
from lib.cfg_helper import model_cfg_bank
from lib.model_zoo import get_model
from lib.experiments.sd_default import color_adjust, auto_merge_imlist
from torch.utils.data import DataLoader, Dataset

from lib.model_zoo.vd import VD
from lib.cfg_holder import cfg_unique_holder as cfguh
from lib.cfg_helper import get_command_line_args, cfg_initiates, load_cfg_yaml
import torchvision.transforms as T
pip

import argparse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-15cd4e243619> in <cell line: 2>()
#       1 import torch
# ----> 2 from lib.cfg_helper import model_cfg_bank
#       3 from lib.model_zoo import get_model
#       4 from lib.experiments.sd_default import color_adjust, auto_merge_imlist
#       5 from torch.utils.data import DataLoader, Dataset
#
# ModuleNotFoundError: No module named 'lib.cfg_helper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
train_stim = np.load('/content/subj01/nsd_train_stim_sub1.npy')
test_stim = np.load('/content/subj01/nsd_test_stim_sub1.npy')

# %%
print(train_captions)
# Out:
# [8859    5]

# %%
# Data Processing for .npy file here!

# %%
import numpy as np
